# %%
import cv2
from skimage import data
import matplotlib.pyplot as plt
pic = data.chelsea()

img = cv2.imread("pic.jpg", 1)

img_1 = cv2.imread("pic.jpg", 0)

img
img_1
# Out:
# array([[80, 80, 81, ..., 70, 70, 70],
#        [80, 80, 81, ..., 70, 70, 70],
#        [80, 81, 81, ..., 70, 70, 70],
#        ...,
#        [83, 83, 84, ..., 86, 86, 86],
#        [82, 82, 83, ..., 87, 87, 87],
#        [81, 81, 82, ..., 89, 89, 89]], dtype=uint8)

# %%
mask = img[:, :, 0] < 255
mask_1 = img_1 < 87
img[mask] = [0, 0, 255]
img_1[mask_1]=1
# plt.imshow(img)
plt.imshow(img_1, 'gray')
